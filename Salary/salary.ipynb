# %%
import numpy
import pandas

# %%
data = pandas.read_csv('Salary.csv')
df = pandas.DataFrame(data)

# %%
X = df.iloc[:,:-1]
X
Y = df.iloc[:,-1]
Y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# 30    127345
# 31    126756
# 32    128765
# 33    135675
# 34    139465
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

model = lr.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([ 37594.71335967, 101162.14637791, 105638.72616793, 148613.89215209,
#         68035.45593179,  56396.34847774, 128021.62511801, 137870.10065605,
#         80569.87934383,  71616.7197638 ,  73407.35167981])

# %%
print(model.coef_)  # slope
print(model.intercept_) # y-intercept (constant)
# Out:
# [8953.15958003]
# 27746.237821634517

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,mean_absolute_percentage_error,r2_score

print(mean_absolute_error(Y_test, Y_pred))
print(mean_squared_error(Y_test, Y_pred))
print(root_mean_squared_error(Y_test, Y_pred))
print(mean_absolute_percentage_error(Y_test, Y_pred))
print(r2_score(Y_test,Y_pred))
# Out:
# 5813.121052223019
# 47804593.185161635
# 6914.086576342651
# 0.06779128848714869
# 0.9541582556358382

# %%
# performance evaluation methods

# MAE  -> Mean Absolute Error

# MSE  -> Mean Squared Error

# RMSE -> Root Mean Squared Error

"""Most commonly used regression evaluation metrics are:"""
# MAPE -> Mean Absolute Percentage Error

# R2 Score -> R squared Score
# Out:
# 'Most commonly used regression evaluation metrics are:'

# %%
# Error = actual output - predicted output

"""
y = actual output

y_ = predicted output

error = y - y_

absolute error = |y - y_|

mean absolute error (MAE) = (1/n) * Σ|y - y_|

"""

# MSE
"""
y = actual output

y_ = predicted output

error = y - y_

MSE = (1/n) * Σ(y - y_)^2

"""

# RMSE
"""
RMSE = sqrt(MSE)

"""

# Mean Absolute Percentage Error (MAPE)
"""
        100      |      (y - y_)      |
MAPE = ------  Σ |--------------------|
         n       |         y          |

"""

# R2 Score
"""
SST (Total Sum of Squares)
SSR (Sum of Squares of Regression)

actual = [3,4,5,6]

predicted = [2.8,4.2,5.1,5.9]

mean of actual = (3+4+5+6)/4 = 4.5

SST = Σ(actual - mean of actual)^2
    = (3-4.5)^2 + (4-4.5)^2 + (5-4.5)^2 + (6-4.5)^2
    = 2.25 + 0.25 + 0.25 + 2.25
    = 5

SSR = Σ(actual - predicted)^2
    = (3-2.8)^2 + (4-4.2)^2 + (5-5.1)^2 + (6-5.9)^2
    = 0.04 + 0.04 + 0.01 + 0.01
    = 0.10

R2 Score = 1 - (SSR/SST)
         = 1 - (0.10/5)
         = 1 - 0.02
         = 0.98

"""
# Out:
# '\nSST (Total Sum of Squares)\nSSR (Sum of Squares of Regression)\n\nactual = [3,4,5,6]\n\npredicted = [2.8,4.2,5.1,5.9]\n\nmean of actual = (3+4+5+6)/4 = 4.5\n\nSST = Σ(actual - mean of actual)^2\n    = (3-4.5)^2 + (4-4.5)^2 + (5-4.5)^2 + (6-4.5)^2\n    = 2.25 + 0.25 + 0.25 + 2.25\n    = 5\n\nSSR = Σ(actual - predicted)^2\n    = (3-2.8)^2 + (4-4.2)^2 + (5-5.1)^2 + (6-5.9)^2\n    = 0.04 + 0.04 + 0.01 + 0.01\n    = 0.10\n\nR2 Score = 1 - (SSR/SST)\n         = 1 - (0.10/5)\n         = 1 - 0.02\n         = 0.98\n\n'
