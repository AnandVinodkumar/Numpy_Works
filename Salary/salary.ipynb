# %%
import numpy
import pandas

# %%
data = pandas.read_csv('Salary.csv')
df = pandas.DataFrame(data)

# %%
X = df.iloc[:,:-1]
X
Y = df.iloc[:,-1]
Y
# Out:
# 0      39343
# 1      46205
# 2      37731
# 3      43525
# 4      39891
# 5      56642
# 6      60150
# 7      54445
# 8      64445
# 9      57189
# 10     63218
# 11     55794
# 12     56957
# 13     57081
# 14     61111
# 15     67938
# 16     66029
# 17     83088
# 18     81363
# 19     93940
# 20     91738
# 21     98273
# 22    101302
# 23    113812
# 24    109431
# 25    105582
# 26    116969
# 27    112635
# 28    122391
# 29    121872
# 30    127345
# 31    126756
# 32    128765
# 33    135675
# 34    139465
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

model = lr.fit(X_train, Y_train)

Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([ 67887.05787754,  63293.37264991, 150573.39197493,  54106.00219464,
#         38487.47242069, 139548.54742861,  75236.95424175, 109230.22492624,
#        123011.28060913,  53187.26514911,  71562.00605965])

# %%
print(model.coef_)  # slope
print(model.intercept_) # y-intercept (constant)
# Out:
# [9187.37045527]
# 26543.890828842443

# %%
# performance evaluation methods

# MAE  -> Mean Absolute Error

# MSE  -> Mean Squared Error

# RMSE -> Root Mean Squared Error

"""Most commonly used regression evaluation metrics are:"""
# MAPE -> Mean Absolute Percentage Error

# R2 Score -> R squared Score
