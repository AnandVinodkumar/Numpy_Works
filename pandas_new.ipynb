# %% [markdown]
# API (Application Programming Interface)
# ==================================================
# Communication between two applications
#
# JSON
# ===========
# Lightweight format to transfer data across applications

# %%
import numpy
# import pandas
# import requests

# data = requests.get("https://jsonplaceholder.typicode.com/posts")
# df = pandas.DataFrame(data.json())
# df
