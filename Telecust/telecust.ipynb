# %%
import numpy
import pandas

# %%
data = pandas.read_csv('Telecust1.csv')
df = pandas.DataFrame(data)
df
# Out:
#      region  tenure  age  income  marital  address  ed  employ  retire  \
# 0         2      13   44      64        1        9   4       5       0
# 1         3      11   33     136        1        7   5       5       0
# 2         3      68   52     116        1       24   1      29       0
# 3         2      33   33      33        0       12   2       0       0
# 4         2      23   30      30        1        9   1       2       0
# ..      ...     ...  ...     ...      ...      ...  ..     ...     ...
# 995       3      10   39      27        0        0   3       0       0
# 996       1       7   34      22        0        2   5       5       0
# 997       3      67   59     944        0       40   5      33       0
# 998       3      70   49      87        0       18   2      22       0
# 999       3      50   36      39        1        7   3       3       0
#
#      gender  reside custcat
# 0         0       2       A
# 1         0       6       D
# ...

# %%
#1
df.head()
#2
df.describe()
#3
df.isna().sum()
#4
df['custcat'].unique()
#5
df[df['income'] > 100]
#6
df[(df['marital'] == 1) & (df['age'] < 40)]
#7
df[(df['gender'] == 0) & (df['retire'] == 1)]
#8
df[df['ed'] > 3]
#9
df.groupby('custcat')['income'].mean()
#10
df.groupby('region')['ed'].count()
#11
df.groupby('marital')['age'].max()
#12
df.groupby('reside')['income'].sum()
#13
df.groupby('gender')[['tenure','income','employ']].mean()
#14
df['income_level'] = df['income'].apply(lambda a: 'High' if a > 100 else ("Medium" if (a > 50) and (a <= 100) else "Low"))
df
#15
df['senior_citizen'] = df['age'].apply(lambda c: 1 if c > 60 else 0)
#16
df['years_until_retirement'] = df['age'].apply(lambda d: (60-d))
df
#17
df[(df['income'] > 100) & (df['ed'] > 3)]
#18
df[(df['marital'] == 0) & (df['income'] > 50) & (df['income'] < 100)]
#19
df.loc[:,['region','age','income','custcat']]
#20
df.tail(3)
#21
# Rename employ to years_employed
df.rename(columns={'employ':'years_employed'})
#22
df['gender'] = df['gender'].replace({0 : "Female",1 : "Male"})
df
# Out:
#      region  tenure  age  income  marital  address  ed  employ  retire  \
# 0         2      13   44      64        1        9   4       5       0
# 1         3      11   33     136        1        7   5       5       0
# 2         3      68   52     116        1       24   1      29       0
# 3         2      33   33      33        0       12   2       0       0
# 4         2      23   30      30        1        9   1       2       0
# ..      ...     ...  ...     ...      ...      ...  ..     ...     ...
# 995       3      10   39      27        0        0   3       0       0
# 996       1       7   34      22        0        2   5       5       0
# 997       3      67   59     944        0       40   5      33       0
# 998       3      70   49      87        0       18   2      22       0
# 999       3      50   36      39        1        7   3       3       0
#
#      gender  reside custcat income_level  senior_citizen  \
# ...
