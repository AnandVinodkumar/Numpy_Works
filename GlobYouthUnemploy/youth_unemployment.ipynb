# %%
import numpy
import pandas

# %%
data = pandas.read_csv('youth_unemployment_global.csv')
df = pandas.DataFrame(data)
df
# Out:
#                            Country CountryCode  Year  YouthUnemployment
# 0      Africa Eastern and Southern          ZH  2024          13.283002
# 1      Africa Eastern and Southern          ZH  2023          13.367810
# 2      Africa Eastern and Southern          ZH  2022          13.620217
# 3      Africa Eastern and Southern          ZH  2021          14.955182
# 4      Africa Eastern and Southern          ZH  2020          14.997030
# ...                            ...         ...   ...                ...
# 17285                     Zimbabwe          ZW  1964                NaN
# 17286                     Zimbabwe          ZW  1963                NaN
# 17287                     Zimbabwe          ZW  1962                NaN
# 17288                     Zimbabwe          ZW  1961                NaN
# 17289                     Zimbabwe          ZW  1960                NaN
#
# [17290 rows x 4 columns]

# %%
df.isna().sum()
# Out:
# Country                 0
# CountryCode            65
# Year                    0
# YouthUnemployment    9309
# dtype: int64

# %%
df = df.dropna(subset=['YouthUnemployment'])
df = df.dropna(subset=['CountryCode'])
df
# Out:
#                            Country CountryCode  Year  YouthUnemployment
# 0      Africa Eastern and Southern          ZH  2024          13.283002
# 1      Africa Eastern and Southern          ZH  2023          13.367810
# 2      Africa Eastern and Southern          ZH  2022          13.620217
# 3      Africa Eastern and Southern          ZH  2021          14.955182
# 4      Africa Eastern and Southern          ZH  2020          14.997030
# ...                            ...         ...   ...                ...
# 17254                     Zimbabwe          ZW  1995          12.241000
# 17255                     Zimbabwe          ZW  1994          10.872000
# 17256                     Zimbabwe          ZW  1993          10.972000
# 17257                     Zimbabwe          ZW  1992          10.919000
# 17258                     Zimbabwe          ZW  1991          10.667000
#
# [7947 rows x 4 columns]

# %%
df.dtypes
# Out:
# Country               object
# CountryCode           object
# Year                   int64
# YouthUnemployment    float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Country'] = le.fit_transform(df['Country'])
df['CountryCode'] = le.fit_transform(df['CountryCode'])

# %%
df
# Out:
#        Country  CountryCode  Year  YouthUnemployment
# 0            1          227  2024          13.283002
# 1            1          227  2023          13.367810
# 2            1          227  2022          13.620217
# 3            1          227  2021          14.955182
# 4            1          227  2020          14.997030
# ...        ...          ...   ...                ...
# 17254      233          233  1995          12.241000
# 17255      233          233  1994          10.872000
# 17256      233          233  1993          10.972000
# 17257      233          233  1992          10.919000
# 17258      233          233  1991          10.667000
#
# [7947 rows x 4 columns]

# %%
X = df.iloc[:,:-1]
Y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

model = lr.fit(X_train,Y_train)

Y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 5
#       1 from sklearn.linear_model import LogisticRegression
#       3 lr = LogisticRegression()
# ----> 5 model = lr.fit(X_train,Y_train)
#       7 Y_pred = model.predict(X_test)
#
# File c:\Users\Anand Vinodkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Anand Vinodkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1256, in LogisticRegression.fit(self, X, y, sample_weight)
#    1245     _dtype = [np.float64, np.float32]
#    1247 X, y = validate_data(
#    1248     self,
#    1249     X,
#    (...)   1254     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1255 )
# -> 1256 check_classification_targets(y)
#    1257 self.classes_ = np.unique(y)
#    1259 # TODO(1.8) remove multi_class
#
# File c:\Users\Anand Vinodkumar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\multiclass.py:221, in check_classification_targets(y)
#     213 y_type = type_of_target(y, input_name="y")
#     214 if y_type not in [
#     215     "binary",
#     216     "multiclass",
#    (...)    219     "multilabel-sequences",
#     220 ]:
# --> 221     raise ValueError(
#     222         f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     223         "classifier, which expects discrete classes on a "
#     224         "regression target with continuous values."
#     225     )
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
from sklearn.metrics import mean_absolute_percentage_error,r2_score

print(mean_absolute_percentage_error(Y_test,Y_pred))
print(r2_score(Y_test,Y_pred))
# Out:
# 1.106806573572637
# 0.016198509252312254
