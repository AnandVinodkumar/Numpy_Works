# %%
# Outlier : It is a datavalue which is very different from the rest of the data

# %%
"""
Hours Studied               Marks
1                           40
2                           50
3                           60
4                           70
5                           80

A                       B
1                       100
2                       80
3                       60
4                       70

"""
"""
python
--------------------
str
function (lambda)
List (methods, map, filter, reduce) module, package, comprehension, regex
file handling, Exception
oops >> Class and object # inheritance, abstraction, polymorphism, encapsulation

GIT

numpy: Why?
difference b/w array and list >> vectorized calculation

pandas : Data preprocessing and analysing

sklearn : training, testing, hyper parameter tuning, etc

nltk : 

matplotlib

SQL  >>

API 
"""
